# %% [markdown]
# # IFC Exploratory Data Analysis
#
# Author: Andrew Bailey
#
# This notebook is for exploring data contained within IFC files. The goal is to explore and understand the core structure of IFC files and identify methods for feature extraction for machine learning models. The notebook uses an example generated by buildingSMART International and can be found at
# [https://github.com/buildingSMART/Sample-Test-Files](https://github.com/buildingSMART/Sample-Test-Files)

# %% [markdown]
# ## File Structure

# %%
# !head -n 20 data/simple_house.ifc
# Out:
# ISO-10303-21;
# HEADER;FILE_DESCRIPTION((
# 'ViewDefinition [CoordinationView_V2.0, QuantityTakeOffAddOnView, SpaceBoundary2ndLevelAddOnView]'
# ,'Option [Drawing Scale: 50.000000]',
# 'Option [Global Unique Identifiers (GUID): Keep existing]',
# 'Option [Elements to export: Visible elements (on all stories)]',
# 'Option [Partial Structure Display: Entire Model]',
# 'Option [IFC Domain: All]','Option [Structural Function: All Elements]',
# 'Option [Convert Grid elements: On]',
# 'Option [Convert IFC Annotations and ArchiCAD 2D elements: Off]',
# 'Option [Convert 2D symbols of Doors and Windows: Off]',
# 'Option [Explode Composite and Complex Profile elements into parts: Off]'
# ,
# 'Option [Export geometries that Participates in Collision Detection only: Off]'
# ,'Option [Multi-skin complex geometries: Building element parts]',
# 'Option [Elements in Solid Element Operations: BRep]',
# 'Option [Elements with junctions: BRep]',
# 'Option [Slabs with slanted edge(s): BRep]',
# 'Option [Use legacy geometric methods as in Coordination View 1.0: Off]'
# ,'Option [IFC Site Geometry: As boundary representation (BRep)]',

# %%
# !tail -n 20 data/simple_house.ifc
# Out:
# #1080865= IFCDIRECTION((0.,0.,-1.));
# #1080867= IFCDIRECTION((4.00637868542E-8,-1.,0.));
# #1080869= IFCCARTESIANPOINT((199.999927663,1805.54958885,2424.));
# #1080871= IFCAXIS2PLACEMENT3D(#1080869,#1080867,#1080865);
# #1080872= IFCPLANE(#1080871);
# #1080873= IFCCARTESIANPOINT((0.,1397.,0.));
# #1080875= IFCCARTESIANPOINT((24.,1397.,0.));
# #1080877= IFCCARTESIANPOINT((24.,0.,0.));
# #1080879= IFCCARTESIANPOINT((0.,0.,0.));
# #1080881= IFCCARTESIANPOINT((0.,1397.,0.));
# #1080883= IFCPOLYLINE((#1080873,#1080875,#1080877,#1080879,#1080881));
# #1080885= IFCCOMPOSITECURVESEGMENT(.CONTINUOUS.,.F.,#1080883);
# #1080886= IFCCOMPOSITECURVE((#1080885),.F.);
# #1080889= IFCCURVEBOUNDEDPLANE(#1080872,#1080886,());
# #1080891= IFCCONNECTIONSURFACEGEOMETRY(#1080889,$);
# #1080892= IFCRELSPACEBOUNDARY('1VdM9r9yo3Bc7KI2cpqKaE',#25,'2ndLevel',
# '2a',#976945,#974861,#1080891,.PHYSICAL.,.EXTERNAL.);
# ENDSEC;
#
# END-ISO-10303-21;
